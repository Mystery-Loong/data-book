# %%
import numpy as np
import pandas as pd

# %%
from datetime import datetime
from datetime import timedelta

# %% [markdown]
# # 11.1 types and tools of date and time data

# %%
now = datetime.now()

# %%
now
# Out:
# datetime.datetime(2025, 11, 27, 22, 57, 58, 416541)

# %%
now.year, now.month, now.day
# Out:
# (2025, 11, 27)

# %%
delta = datetime(2011, 1, 7) - datetime(2008, 6, 24, 8,15)

# %%
delta
# Out:
# datetime.timedelta(days=926, seconds=56700)

# %%
delta.days
# Out:
# 926

# %%
delta.seconds
# Out:
# 56700

# %%
start = datetime(2011, 1, 7)

# %%
start + timedelta(12)
# Out:
# datetime.datetime(2011, 1, 19, 0, 0)

# %%
start - 2 * timedelta(12)
# Out:
# datetime.datetime(2010, 12, 14, 0, 0)

# %%
stamp = datetime(2011, 1, 3)

# %%
str(stamp)
# Out:
# '2011-01-03 00:00:00'

# %%
stamp.strftime("%Y-%M-%d")
# Out:
# '2011-00-03'

# %%
value = "2011-01-03"

# %%
datetime.strptime(value, "%Y-%m-%d")
# Out:
# datetime.datetime(2011, 1, 3, 0, 0)

# %%
datestrs = ["7/6/2011", "8/6/2011"]

# %%
[datetime.strptime(x, "%m/%d/%Y") for x in datestrs]
# Out:
# [datetime.datetime(2011, 7, 6, 0, 0), datetime.datetime(2011, 8, 6, 0, 0)]

# %%
datestrs = ["2011-07-06 12:00:00", "2011-08-06 00:00:00"]

# %%
pd.to_datetime(datestrs)
# Out:
# DatetimeIndex(['2011-07-06 12:00:00', '2011-08-06 00:00:00'], dtype='datetime64[ns]', freq=None)

# %%
idx = pd.to_datetime(datestrs + [None])

# %%
idx
# Out:
# DatetimeIndex(['2011-07-06 12:00:00', '2011-08-06 00:00:00', 'NaT'], dtype='datetime64[ns]', freq=None)

# %%
idx[2]
# Out:
# NaT

# %%
pd.isna(idx)
# Out:
# array([False, False,  True])

# %% [markdown]
# # 11.2 basic knowledge of time series

# %%
dates = [datetime(2011, 1, 2), datetime(2011, 1, 5),
         datetime(2011, 1, 7), datetime(2011, 1, 8),
         datetime(2011, 1, 10), datetime(2011, 1, 12)]

# %%
ts = pd.Series(np.random.standard_normal(6), index=dates)

# %%
ts
# Out:
# 2011-01-02    0.896451
# 2011-01-05    0.392169
# 2011-01-07    0.479198
# 2011-01-08   -0.835518
# 2011-01-10   -0.472047
# 2011-01-12    0.742820
# dtype: float64

# %%
ts.index
# Out:
# DatetimeIndex(['2011-01-02', '2011-01-05', '2011-01-07', '2011-01-08',
#                '2011-01-10', '2011-01-12'],
#               dtype='datetime64[ns]', freq=None)

# %%
ts +ts[::2]
# Out:
# 2011-01-02    1.792902
# 2011-01-05         NaN
# 2011-01-07    0.958395
# 2011-01-08         NaN
# 2011-01-10   -0.944093
# 2011-01-12         NaN
# dtype: float64

# %%
ts.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
stamp = ts.index[0]

# %%
stamp
# Out:
# Timestamp('2011-01-02 00:00:00')

# %% [markdown]
# # 11.2.1 index select subset construction

# %%
stamp = ts.index[2]

# %%
ts[stamp]
# Out:
# np.float64(0.479197542570693)

# %%
ts["2011-01-10"]
# Out:
# np.float64(-0.4720467265190769)

# %%
longer_ts = pd.Series(np.random.standard_normal(1000),
                      index=pd.date_range("2000-01-01", periods=1000))

# %%
longer_ts
# Out:
# 2000-01-01    0.614432
# 2000-01-02   -0.283337
# 2000-01-03    0.390954
# 2000-01-04   -0.318437
# 2000-01-05    0.938494
#                 ...
# 2002-09-22   -0.014015
# 2002-09-23   -2.150207
# 2002-09-24    0.162403
# 2002-09-25   -0.122347
# 2002-09-26    1.155841
# Freq: D, Length: 1000, dtype: float64

# %%
longer_ts["2001"]
# Out:
# 2001-01-01    0.459806
# 2001-01-02   -1.868321
# 2001-01-03    0.312425
# 2001-01-04    0.908186
# 2001-01-05   -0.970926
#                 ...
# 2001-12-27   -0.003316
# 2001-12-28    1.028842
# 2001-12-29   -0.298293
# 2001-12-30   -1.834696
# 2001-12-31   -1.145734
# Freq: D, Length: 365, dtype: float64

# %%
longer_ts["2001-05"]
# Out:
# 2001-05-01    1.152031
# 2001-05-02    0.123884
# 2001-05-03   -0.820007
# 2001-05-04   -1.099892
# 2001-05-05   -0.135450
# 2001-05-06    0.352690
# 2001-05-07    0.664094
# 2001-05-08    1.329382
# 2001-05-09    0.981462
# 2001-05-10   -0.708138
# 2001-05-11   -0.376161
# 2001-05-12   -0.587798
# 2001-05-13   -1.413188
# 2001-05-14   -0.242979
# 2001-05-15    0.298819
# 2001-05-16    0.999171
# 2001-05-17   -0.317130
# 2001-05-18    1.764153
# 2001-05-19    0.523460
# 2001-05-20   -1.306773
# 2001-05-21    1.391172
# 2001-05-22   -0.794303
# 2001-05-23   -0.567691
# 2001-05-24   -0.096321
# 2001-05-25    0.036762
# 2001-05-26    0.609787
# 2001-05-27    0.706748
# 2001-05-28    0.145288
# 2001-05-29   -1.085764
# 2001-05-30   -0.935875
# 2001-05-31    0.592020
# Freq: D, dtype: float64

# %%
ts[datetime(2011, 1, 7):]
# Out:
# 2011-01-07    0.479198
# 2011-01-08   -0.835518
# 2011-01-10   -0.472047
# 2011-01-12    0.742820
# dtype: float64

# %%
ts[datetime(2011, 1, 7):datetime(2011, 1, 10)]
# Out:
# 2011-01-07    0.479198
# 2011-01-08   -0.835518
# 2011-01-10   -0.472047
# dtype: float64

# %%
ts
# Out:
# 2011-01-02    0.896451
# 2011-01-05    0.392169
# 2011-01-07    0.479198
# 2011-01-08   -0.835518
# 2011-01-10   -0.472047
# 2011-01-12    0.742820
# dtype: float64

# %%
ts["2011-01-06":"2011-01-11"]
# Out:
# 2011-01-07    0.479198
# 2011-01-08   -0.835518
# 2011-01-10   -0.472047
# dtype: float64

# %%
ts.truncate(after="2011-01-09")
# Out:
# 2011-01-02    0.896451
# 2011-01-05    0.392169
# 2011-01-07    0.479198
# 2011-01-08   -0.835518
# dtype: float64

# %%
dates = pd.date_range("2000-01-01", periods=100, freq="W-WED")

# %%
long_df = pd.DataFrame(np.random.standard_normal((100,4)),
                       index=dates,
                       columns=["Colorado", "Texas",
                                "New York", "Ohio"])

# %%
long_df.loc["2001-05"]
# Out:
#             Colorado     Texas  New York      Ohio
# 2001-05-02  0.742966 -1.653542 -0.380563  0.996330
# 2001-05-09 -1.046851 -1.702170 -0.077089  0.063257
# 2001-05-16 -2.072288 -1.238279 -0.070954  1.268729
# 2001-05-23 -0.915861 -1.791139  1.058960 -2.996582
# 2001-05-30 -0.227950 -0.520292  0.285469  0.038844

# %% [markdown]
# # 11.2.2 time series with duplicate indexes

# %%
dates = pd.DatetimeIndex(["2000-01-01", "2000-01-02", "2000-01-02",
                      "2000-01-02", "2000-01-03"])

# %%
dup_ts = pd.Series(np.arange(5), index=dates)

# %%
dup_ts
# Out:
# 2000-01-01    0
# 2000-01-02    1
# 2000-01-02    2
# 2000-01-02    3
# 2000-01-03    4
# dtype: int64

# %%
dup_ts.index.is_unique
# Out:
# False

# %%
dup_ts["2000-01-03"]
# Out:
# np.int64(4)

# %%
dup_ts["2000-01-02"]
# Out:
# 2000-01-02    1
# 2000-01-02    2
# 2000-01-02    3
# dtype: int64

# %%
grouped = dup_ts.groupby(level=0)

# %%
grouped.mean()
# Out:
# 2000-01-01    0.0
# 2000-01-02    2.0
# 2000-01-03    4.0
# dtype: float64

# %%
grouped.count()
# Out:
# 2000-01-01    1
# 2000-01-02    3
# 2000-01-03    1
# dtype: int64

# %% [markdown]
# # 11.3 Range,frequency,and shift of dates

# %%
ts
# Out:
# 2011-01-02    0.896451
# 2011-01-05    0.392169
# 2011-01-07    0.479198
# 2011-01-08   -0.835518
# 2011-01-10   -0.472047
# 2011-01-12    0.742820
# dtype: float64

# %%
resampler = ts.resample("D")

# %%
resampler

# %% [markdown]
# # 11.3.1 Generate date range

# %%
index = pd.date_range("2012-04-01", "2012-06-01")

# %%
index
# Out:
# DatetimeIndex(['2012-04-01', '2012-04-02', '2012-04-03', '2012-04-04',
#                '2012-04-05', '2012-04-06', '2012-04-07', '2012-04-08',
#                '2012-04-09', '2012-04-10', '2012-04-11', '2012-04-12',
#                '2012-04-13', '2012-04-14', '2012-04-15', '2012-04-16',
#                '2012-04-17', '2012-04-18', '2012-04-19', '2012-04-20',
#                '2012-04-21', '2012-04-22', '2012-04-23', '2012-04-24',
#                '2012-04-25', '2012-04-26', '2012-04-27', '2012-04-28',
#                '2012-04-29', '2012-04-30', '2012-05-01', '2012-05-02',
#                '2012-05-03', '2012-05-04', '2012-05-05', '2012-05-06',
#                '2012-05-07', '2012-05-08', '2012-05-09', '2012-05-10',
#                '2012-05-11', '2012-05-12', '2012-05-13', '2012-05-14',
#                '2012-05-15', '2012-05-16', '2012-05-17', '2012-05-18',
#                '2012-05-19', '2012-05-20', '2012-05-21', '2012-05-22',
#                '2012-05-23', '2012-05-24', '2012-05-25', '2012-05-26',
#                '2012-05-27', '2012-05-28', '2012-05-29', '2012-05-30',
#                '2012-05-31', '2012-06-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start="2012-04-01", periods=20)
# Out:
# DatetimeIndex(['2012-04-01', '2012-04-02', '2012-04-03', '2012-04-04',
#                '2012-04-05', '2012-04-06', '2012-04-07', '2012-04-08',
#                '2012-04-09', '2012-04-10', '2012-04-11', '2012-04-12',
#                '2012-04-13', '2012-04-14', '2012-04-15', '2012-04-16',
#                '2012-04-17', '2012-04-18', '2012-04-19', '2012-04-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(end="2012-06-01", periods=20)
# Out:
# DatetimeIndex(['2012-05-13', '2012-05-14', '2012-05-15', '2012-05-16',
#                '2012-05-17', '2012-05-18', '2012-05-19', '2012-05-20',
#                '2012-05-21', '2012-05-22', '2012-05-23', '2012-05-24',
#                '2012-05-25', '2012-05-26', '2012-05-27', '2012-05-28',
#                '2012-05-29', '2012-05-30', '2012-05-31', '2012-06-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range("2000-01-01", "2000-12-01", freq="BM")
# Out:
# /tmp/ipykernel_3803/3742551278.py:1: FutureWarning: 'BM' is deprecated and will be removed in a future version, please use 'BME' instead.
#   pd.date_range("2000-01-01", "2000-12-01", freq="BM")
# DatetimeIndex(['2000-01-31', '2000-02-29', '2000-03-31', '2000-04-28',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-29', '2000-10-31', '2000-11-30'],
#               dtype='datetime64[ns]', freq='BME')

# %%
pd.date_range("2012-05-02 12:56:31", periods=5)
# Out:
# DatetimeIndex(['2012-05-02 12:56:31', '2012-05-03 12:56:31',
#                '2012-05-04 12:56:31', '2012-05-05 12:56:31',
#                '2012-05-06 12:56:31'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range("2012-05-02 12:56:31", periods=5, normalize=True)
# Out:
# DatetimeIndex(['2012-05-02', '2012-05-03', '2012-05-04', '2012-05-05',
#                '2012-05-06'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# # 11.3.2 Frequency and date offset

# %%
from pandas.tseries.offsets import Hour, Minute

# %%
hour = Hour()

# %%
hour

# %%
four_hours = Hour(4)

# %%
four_hours
# Out:
# <4 * Hours>

# %%
pd.date_range("2000-01-01", "2000-01-03 23:59", freq="4H")
# Out:
# /tmp/ipykernel_3803/3449897904.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   pd.date_range("2000-01-01", "2000-01-03 23:59", freq="4H")
# DatetimeIndex(['2000-01-01 00:00:00', '2000-01-01 04:00:00',
#                '2000-01-01 08:00:00', '2000-01-01 12:00:00',
#                '2000-01-01 16:00:00', '2000-01-01 20:00:00',
#                '2000-01-02 00:00:00', '2000-01-02 04:00:00',
#                '2000-01-02 08:00:00', '2000-01-02 12:00:00',
#                '2000-01-02 16:00:00', '2000-01-02 20:00:00',
#                '2000-01-03 00:00:00', '2000-01-03 04:00:00',
#                '2000-01-03 08:00:00', '2000-01-03 12:00:00',
#                '2000-01-03 16:00:00', '2000-01-03 20:00:00'],
#               dtype='datetime64[ns]', freq='4h')

# %%
Hour(2) + Minute(30)
# Out:
# <150 * Minutes>

# %%
pd.date_range("2000-01-01", periods=10, freq="1h30min")
# Out:
# DatetimeIndex(['2000-01-01 00:00:00', '2000-01-01 01:30:00',
#                '2000-01-01 03:00:00', '2000-01-01 04:30:00',
#                '2000-01-01 06:00:00', '2000-01-01 07:30:00',
#                '2000-01-01 09:00:00', '2000-01-01 10:30:00',
#                '2000-01-01 12:00:00', '2000-01-01 13:30:00'],
#               dtype='datetime64[ns]', freq='90min')

# %%
monthly_dates = pd.date_range("2012-01-01", "2012-09-01", freq="WOM-3FRI")

# %%
list(monthly_dates)
# Out:
# [Timestamp('2012-01-20 00:00:00'),
#  Timestamp('2012-02-17 00:00:00'),
#  Timestamp('2012-03-16 00:00:00'),
#  Timestamp('2012-04-20 00:00:00'),
#  Timestamp('2012-05-18 00:00:00'),
#  Timestamp('2012-06-15 00:00:00'),
#  Timestamp('2012-07-20 00:00:00'),
#  Timestamp('2012-08-17 00:00:00')]

# %% [markdown]
# # 11.3.3 Shift the leading and lagging data

# %%
ts = pd.Series(np.random.standard_normal(4),
               index=pd.date_range("2000-01-01", periods=4, freq="M"))
# Out:
# /tmp/ipykernel_3803/2098005487.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   index=pd.date_range("2000-01-01", periods=4, freq="M"))

# %%
ts
# Out:
# 2000-01-31    0.958048
# 2000-02-29   -1.178220
# 2000-03-31   -1.677967
# 2000-04-30    1.637331
# Freq: ME, dtype: float64

# %%
ts.shift(2)
# Out:
# 2000-01-31         NaN
# 2000-02-29         NaN
# 2000-03-31    0.958048
# 2000-04-30   -1.178220
# Freq: ME, dtype: float64

# %%
ts.shift(-2)
# Out:
# 2000-01-31   -1.677967
# 2000-02-29    1.637331
# 2000-03-31         NaN
# 2000-04-30         NaN
# Freq: ME, dtype: float64

# %%
ts.shift(2, freq="M")
# Out:
# /tmp/ipykernel_3803/903147437.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   ts.shift(2, freq="M")
# 2000-03-31    0.958048
# 2000-04-30   -1.178220
# 2000-05-31   -1.677967
# 2000-06-30    1.637331
# Freq: ME, dtype: float64

# %%
ts.shift(2, freq="ME")
# Out:
# 2000-03-31    0.958048
# 2000-04-30   -1.178220
# 2000-05-31   -1.677967
# 2000-06-30    1.637331
# Freq: ME, dtype: float64

# %%
ts.shift(3, freq="D")
# Out:
# 2000-02-03    0.958048
# 2000-03-03   -1.178220
# 2000-04-03   -1.677967
# 2000-05-03    1.637331
# dtype: float64

# %%
ts.shift(1, freq="90T")
# Out:
# /tmp/ipykernel_3803/584021106.py:1: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   ts.shift(1, freq="90T")
# 2000-01-31 01:30:00    0.958048
# 2000-02-29 01:30:00   -1.178220
# 2000-03-31 01:30:00   -1.677967
# 2000-04-30 01:30:00    1.637331
# dtype: float64

# %%
ts.shift(1, freq="90min")
# Out:
# 2000-01-31 01:30:00    0.958048
# 2000-02-29 01:30:00   -1.178220
# 2000-03-31 01:30:00   -1.677967
# 2000-04-30 01:30:00    1.637331
# dtype: float64

# %%
from pandas.tseries.offsets import Day, MonthEnd

# %%
now = datetime(2011, 11, 17)

# %%
now + 3 * Day()
# Out:
# Timestamp('2011-11-20 00:00:00')

# %%
now + MonthEnd()
# Out:
# Timestamp('2011-11-30 00:00:00')

# %%
now + MonthEnd(2)
# Out:
# Timestamp('2011-12-31 00:00:00')

# %%
offset = MonthEnd()

# %%
offset.rollforward(now)
# Out:
# Timestamp('2011-11-30 00:00:00')

# %%
offset.rollback(now)
# Out:
# Timestamp('2011-10-31 00:00:00')

# %%
ts = pd.Series(np.random.standard_normal(20),
               index=pd.date_range("2000-01-15", periods=20, freq="4D"))

# %%
ts
# Out:
# 2000-01-15    0.044361
# 2000-01-19    2.022957
# 2000-01-23    0.627567
# 2000-01-27    0.415102
# 2000-01-31    0.949803
# 2000-02-04   -0.104326
# 2000-02-08    0.829467
# 2000-02-12    2.444842
# 2000-02-16   -0.200860
# 2000-02-20   -0.715595
# 2000-02-24   -0.373711
# 2000-02-28   -0.572483
# 2000-03-03   -0.300423
# 2000-03-07    0.195835
# 2000-03-11    0.751060
# 2000-03-15    0.862092
# 2000-03-19   -0.585418
# 2000-03-23    0.670986
# 2000-03-27    0.131693
# 2000-03-31   -0.567010
# Freq: 4D, dtype: float64

# %%
ts.groupby(MonthEnd().rollforward).mean()
# Out:
# 2000-01-31    0.811958
# 2000-02-29    0.186762
# 2000-03-31    0.144852
# dtype: float64

# %%
ts.resample("ME").mean()
# Out:
# 2000-01-31    0.811958
# 2000-02-29    0.186762
# 2000-03-31    0.144852
# Freq: ME, dtype: float64

# %% [markdown]
# # 11.4 Time zone process

# %%
import pytz

# %%
pytz.common_timezones[-5:]
# Out:
# ['US/Eastern', 'US/Hawaii', 'US/Mountain', 'US/Pacific', 'UTC']

# %%
tz = pytz.timezone("America/New_York")

# %%
tz
# Out:
# <DstTzInfo 'America/New_York' LMT-1 day, 19:04:00 STD>

# %% [markdown]
# # 11.4.1 Localization and Conversion of Time zones

# %%
dates = pd.date_range("2012-03-09 09:30", periods=6)

# %%
ts = pd.Series(np.random.standard_normal(len(dates)), index=dates)

# %%
ts
# Out:
# 2012-03-09 09:30:00   -0.675375
# 2012-03-10 09:30:00   -0.064931
# 2012-03-11 09:30:00   -1.845022
# 2012-03-12 09:30:00   -0.150172
# 2012-03-13 09:30:00    0.614893
# 2012-03-14 09:30:00   -0.758630
# Freq: D, dtype: float64

# %%
print(ts.index.tz)
# Out:
# None

# %%
pd.date_range("2012-03-09 09:30", periods=10, tz="UTC")
# Out:
# DatetimeIndex(['2012-03-09 09:30:00+00:00', '2012-03-10 09:30:00+00:00',
#                '2012-03-11 09:30:00+00:00', '2012-03-12 09:30:00+00:00',
#                '2012-03-13 09:30:00+00:00', '2012-03-14 09:30:00+00:00',
#                '2012-03-15 09:30:00+00:00', '2012-03-16 09:30:00+00:00',
#                '2012-03-17 09:30:00+00:00', '2012-03-18 09:30:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='D')

# %%
ts
# Out:
# 2012-03-09 09:30:00   -0.675375
# 2012-03-10 09:30:00   -0.064931
# 2012-03-11 09:30:00   -1.845022
# 2012-03-12 09:30:00   -0.150172
# 2012-03-13 09:30:00    0.614893
# 2012-03-14 09:30:00   -0.758630
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")

# %%
ts_utc
# Out:
# 2012-03-09 09:30:00+00:00   -0.675375
# 2012-03-10 09:30:00+00:00   -0.064931
# 2012-03-11 09:30:00+00:00   -1.845022
# 2012-03-12 09:30:00+00:00   -0.150172
# 2012-03-13 09:30:00+00:00    0.614893
# 2012-03-14 09:30:00+00:00   -0.758630
# Freq: D, dtype: float64

# %%
ts_utc.index
# Out:
# DatetimeIndex(['2012-03-09 09:30:00+00:00', '2012-03-10 09:30:00+00:00',
#                '2012-03-11 09:30:00+00:00', '2012-03-12 09:30:00+00:00',
#                '2012-03-13 09:30:00+00:00', '2012-03-14 09:30:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='D')

# %%
ts_utc.tz_convert("America/New_York")
# Out:
# 2012-03-09 04:30:00-05:00   -0.675375
# 2012-03-10 04:30:00-05:00   -0.064931
# 2012-03-11 05:30:00-04:00   -1.845022
# 2012-03-12 05:30:00-04:00   -0.150172
# 2012-03-13 05:30:00-04:00    0.614893
# 2012-03-14 05:30:00-04:00   -0.758630
# Freq: D, dtype: float64

# %%
ts_eastern = ts.tz_localize("America/New_York")

# %%
ts_eastern.tz_convert("UTC")
# Out:
# 2012-03-09 14:30:00+00:00   -0.675375
# 2012-03-10 14:30:00+00:00   -0.064931
# 2012-03-11 13:30:00+00:00   -1.845022
# 2012-03-12 13:30:00+00:00   -0.150172
# 2012-03-13 13:30:00+00:00    0.614893
# 2012-03-14 13:30:00+00:00   -0.758630
# dtype: float64

# %%
ts_eastern.tz_convert("Europe/Berlin")
# Out:
# 2012-03-09 15:30:00+01:00   -0.675375
# 2012-03-10 15:30:00+01:00   -0.064931
# 2012-03-11 14:30:00+01:00   -1.845022
# 2012-03-12 14:30:00+01:00   -0.150172
# 2012-03-13 14:30:00+01:00    0.614893
# 2012-03-14 14:30:00+01:00   -0.758630
# dtype: float64

# %%
ts.index.tz_localize("Asia/Shanghai")
# Out:
# DatetimeIndex(['2012-03-09 09:30:00+08:00', '2012-03-10 09:30:00+08:00',
#                '2012-03-11 09:30:00+08:00', '2012-03-12 09:30:00+08:00',
#                '2012-03-13 09:30:00+08:00', '2012-03-14 09:30:00+08:00'],
#               dtype='datetime64[ns, Asia/Shanghai]', freq=None)

# %% [markdown]
# # 11.4.2 Operation on time zone type timestamp objects

# %%
stamp = pd.Timestamp("2011-03-12 04:00")

# %%
stamp_utc = stamp.tz_localize("utc")

# %%
stamp_utc.tz_convert("America/New_York")
# Out:
# Timestamp('2011-03-11 23:00:00-0500', tz='America/New_York')

# %%
stamp_moscow = pd.Timestamp("2011-03-12 04:00", tz="Europe/Moscow")

# %%
stamp_moscow
# Out:
# Timestamp('2011-03-12 04:00:00+0300', tz='Europe/Moscow')

# %%
stamp_utc.value
# Out:
# 1299902400000000000

# %%
stamp_utc.tz_convert("America/New_York").value
# Out:
# 1299902400000000000

# %%
stamp = pd.Timestamp("2012-03-11 01:30", tz="US/Eastern")

# %%
stamp
# Out:
# Timestamp('2012-03-11 01:30:00-0500', tz='US/Eastern')

# %%
stamp + Hour()
# Out:
# Timestamp('2012-03-11 03:30:00-0400', tz='US/Eastern')

# %%
stamp = pd.Timestamp("2012-11-04 00:30", tz="US/Eastern")

# %%
stamp
# Out:
# Timestamp('2012-11-04 00:30:00-0400', tz='US/Eastern')

# %%
stamp + 2 * Hour()
# Out:
# Timestamp('2012-11-04 01:30:00-0500', tz='US/Eastern')

# %% [markdown]
# # 11.4.3 Operations between differrent time zones

# %%
dates = pd.date_range("2012-03-07 09:30", periods=10, freq="B")

# %%
ts = pd.Series(np.random.standard_normal(len(dates)), index=dates)

# %%
ts
# Out:
# 2012-03-07 09:30:00    1.532798
# 2012-03-08 09:30:00   -0.073201
# 2012-03-09 09:30:00    0.060112
# 2012-03-12 09:30:00   -1.605670
# 2012-03-13 09:30:00    1.176149
# 2012-03-14 09:30:00    0.797907
# 2012-03-15 09:30:00   -0.588046
# 2012-03-16 09:30:00    1.162577
# 2012-03-19 09:30:00   -1.340366
# 2012-03-20 09:30:00   -0.425456
# Freq: B, dtype: float64

# %%
ts1 = ts[:7].tz_localize("Europe/London")

# %%
ts2 = ts1[2:].tz_convert("Europe/Moscow")

# %%
result = ts1 + ts2

# %%
result.index
# Out:
# DatetimeIndex(['2012-03-07 09:30:00+00:00', '2012-03-08 09:30:00+00:00',
#                '2012-03-09 09:30:00+00:00', '2012-03-12 09:30:00+00:00',
#                '2012-03-13 09:30:00+00:00', '2012-03-14 09:30:00+00:00',
#                '2012-03-15 09:30:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq=None)

# %% [markdown]
# # 11.5 Cycle and its arithmetic operations

# %%
p = pd.Period("2011", freq="A-DEC")
# Out:
# /tmp/ipykernel_3803/3436265626.py:1: FutureWarning: 'A-DEC' is deprecated and will be removed in a future version, please use 'Y-DEC' instead.
#   p = pd.Period("2011", freq="A-DEC")

# %%
p
# Out:
# Period('2011', 'Y-DEC')

# %%
p + 5
# Out:
# Period('2016', 'Y-DEC')

# %%
p - 2
# Out:
# Period('2009', 'Y-DEC')

# %%
pd.Period("2014", freq="A-DEC") - p
# Out:
# /tmp/ipykernel_3803/3816979827.py:1: FutureWarning: 'A-DEC' is deprecated and will be removed in a future version, please use 'Y-DEC' instead.
#   pd.Period("2014", freq="A-DEC") - p
# <3 * YearEnds: month=12>

# %%
periods = pd.period_range("2000-01-01", "2000-06-30", freq="M")

# %%
periods
# Out:
# PeriodIndex(['2000-01', '2000-02', '2000-03', '2000-04', '2000-05', '2000-06'], dtype='period[M]')

# %%
pd.Series(np.random.standard_normal(6), index=periods)
# Out:
# 2000-01   -0.119141
# 2000-02    0.881448
# 2000-03    0.904720
# 2000-04    0.406796
# 2000-05   -0.924437
# 2000-06    0.763818
# Freq: M, dtype: float64

# %%
values = ["2001Q3", "2002Q2", "2003Q1"]

# %%
index = pd.PeriodIndex(values, freq="Q-DEC")

# %%
index
# Out:
# PeriodIndex(['2001Q3', '2002Q2', '2003Q1'], dtype='period[Q-DEC]')

# %% [markdown]
# # 11.5.1 Frequency conversion of cycles

# %%
p = pd.Period("2011", freq="A-DEC")
# Out:
# /tmp/ipykernel_3803/3436265626.py:1: FutureWarning: 'A-DEC' is deprecated and will be removed in a future version, please use 'Y-DEC' instead.
#   p = pd.Period("2011", freq="A-DEC")

# %%
p
# Out:
# Period('2011', 'Y-DEC')

# %%
p.asfreq("M", how="start")
# Out:
# Period('2011-01', 'M')

# %%
p.asfreq("M", how="end")
# Out:
# Period('2011-12', 'M')

# %%
p.asfreq("M")
# Out:
# Period('2011-12', 'M')

# %%
p = pd.Period("2011", freq="A-JUN")
# Out:
# /tmp/ipykernel_3803/3595438442.py:1: FutureWarning: 'A-JUN' is deprecated and will be removed in a future version, please use 'Y-JUN' instead.
#   p = pd.Period("2011", freq="A-JUN")

# %%
p
# Out:
# Period('2011', 'Y-JUN')

# %%
p.asfreq("M", how="start")
# Out:
# Period('2010-07', 'M')

# %%
p.asfreq("M", how="end")
# Out:
# Period('2011-06', 'M')

# %%
p = pd.Period("Aug-2011", "M")

# %%
p.asfreq("A-JUN")
# Out:
# /tmp/ipykernel_3803/1565973874.py:1: FutureWarning: 'A-JUN' is deprecated and will be removed in a future version, please use 'Y-JUN' instead.
#   p.asfreq("A-JUN")
# Period('2012', 'Y-JUN')

# %%
periods = pd.period_range("2006", "2009", freq="A-DEC")
# Out:
# /tmp/ipykernel_3803/3066967862.py:1: FutureWarning: 'A-DEC' is deprecated and will be removed in a future version, please use 'Y-DEC' instead.
#   periods = pd.period_range("2006", "2009", freq="A-DEC")

# %%
ts = pd.Series(np.random.standard_normal(len(periods)), index=periods)

# %%
ts
# Out:
# 2006    0.136455
# 2007   -0.634764
# 2008   -0.743524
# 2009    1.023104
# Freq: Y-DEC, dtype: float64

# %%
ts.asfreq("M", how="start")
# Out:
# 2006-01    0.136455
# 2007-01   -0.634764
# 2008-01   -0.743524
# 2009-01    1.023104
# Freq: M, dtype: float64

# %%
ts.asfreq("B", how="end")
# Out:
# /tmp/ipykernel_3803/2984082239.py:1: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   ts.asfreq("B", how="end")
# 2006-12-29    0.136455
# 2007-12-31   -0.634764
# 2008-12-31   -0.743524
# 2009-12-31    1.023104
# Freq: B, dtype: float64

# %% [markdown]
# # 11.5.2 Quarterly cycle frequency

# %%
p = pd.Period("2012Q4", freq="Q-JAN")

# %%
p
# Out:
# Period('2012Q4', 'Q-JAN')

# %%
p.asfreq("D", how="start")
# Out:
# Period('2011-11-01', 'D')

# %%
p.asfreq("D", how="end")
# Out:
# Period('2012-01-31', 'D')

# %%
p4pm = (p.asfreq("B", how="end") - 1).asfreq("T", how="start") + 16 * 60
# Out:
# /tmp/ipykernel_3803/2204560885.py:1: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   p4pm = (p.asfreq("B", how="end") - 1).asfreq("T", how="start") + 16 * 60
# /tmp/ipykernel_3803/2204560885.py:1: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   p4pm = (p.asfreq("B", how="end") - 1).asfreq("T", how="start") + 16 * 60

# %%
p4pm
# Out:
# Period('2012-01-30 16:00', 'min')

# %%
p4pm.to_timestamp()
# Out:
# Timestamp('2012-01-30 16:00:00')

# %%
periods = pd.period_range("2011Q3", "2012Q4", freq="Q-JAN")

# %%
ts = pd.Series(np.arange(len(periods)), index=periods)

# %%
ts
# Out:
# 2011Q3    0
# 2011Q4    1
# 2012Q1    2
# 2012Q2    3
# 2012Q3    4
# 2012Q4    5
# Freq: Q-JAN, dtype: int64

# %%
new_periods = (periods.asfreq("B", "end") - 1).asfreq("H", "start") + 16
# Out:
# /tmp/ipykernel_3803/3213338784.py:1: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   new_periods = (periods.asfreq("B", "end") - 1).asfreq("H", "start") + 16
# /tmp/ipykernel_3803/3213338784.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   new_periods = (periods.asfreq("B", "end") - 1).asfreq("H", "start") + 16

# %%
ts.index = new_periods.to_timestamp()

# %%
ts
# Out:
# 2010-10-28 16:00:00    0
# 2011-01-28 16:00:00    1
# 2011-04-28 16:00:00    2
# 2011-07-28 16:00:00    3
# 2011-10-28 16:00:00    4
# 2012-01-30 16:00:00    5
# dtype: int64

# %% [markdown]
# # 11.5.3 Conversion between timestamp and period

# %%
dates = pd.date_range("2000-01-01", periods=3, freq="M")
# Out:
# /tmp/ipykernel_3803/1909817033.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range("2000-01-01", periods=3, freq="M")

# %%
ts = pd.Series(np.random.standard_normal(3), index=dates)

# %%
ts
# Out:
# 2000-01-31    0.758890
# 2000-02-29   -0.437919
# 2000-03-31    1.162288
# Freq: ME, dtype: float64

# %%
pts = ts.to_period()

# %%
pts
# Out:
# 2000-01    0.758890
# 2000-02   -0.437919
# 2000-03    1.162288
# Freq: M, dtype: float64

# %%
dates = pd.date_range("2000-01-29", periods=6)

# %%
ts2 = pd.Series(np.random.standard_normal(6), index=dates)

# %%
ts2
# Out:
# 2000-01-29   -0.226446
# 2000-01-30    2.459283
# 2000-01-31   -1.356171
# 2000-02-01    0.744451
# 2000-02-02    1.182222
# 2000-02-03   -0.951160
# Freq: D, dtype: float64

# %%
ts2.to_period("M")
# Out:
# 2000-01   -0.226446
# 2000-01    2.459283
# 2000-01   -1.356171
# 2000-02    0.744451
# 2000-02    1.182222
# 2000-02   -0.951160
# Freq: M, dtype: float64

# %%
pts = ts2.to_period()

# %%
pts
# Out:
# 2000-01-29   -0.226446
# 2000-01-30    2.459283
# 2000-01-31   -1.356171
# 2000-02-01    0.744451
# 2000-02-02    1.182222
# 2000-02-03   -0.951160
# Freq: D, dtype: float64

# %%
pts.to_timestamp(how="end")
# Out:
# 2000-01-29 23:59:59.999999999   -0.226446
# 2000-01-30 23:59:59.999999999    2.459283
# 2000-01-31 23:59:59.999999999   -1.356171
# 2000-02-01 23:59:59.999999999    0.744451
# 2000-02-02 23:59:59.999999999    1.182222
# 2000-02-03 23:59:59.999999999   -0.951160
# Freq: D, dtype: float64

# %% [markdown]
# # 11.5.4 Create PeriodIndex through an arrany

# %%
data = pd.read_csv("examples/macrodata.csv")

# %%
data
# Out:
#      year  quarter    realgdp  realcons   realinv  realgovt  realdpi      cpi  \
# 0    1959        1   2710.349    1707.4   286.898   470.045   1886.9   28.980
# 1    1959        2   2778.801    1733.7   310.859   481.301   1919.7   29.150
# 2    1959        3   2775.488    1751.8   289.226   491.260   1916.4   29.350
# 3    1959        4   2785.204    1753.7   299.356   484.052   1931.3   29.370
# 4    1960        1   2847.699    1770.5   331.722   462.199   1955.5   29.540
# ..    ...      ...        ...       ...       ...       ...      ...      ...
# 198  2008        3  13324.600    9267.7  1990.693   991.551   9838.3  216.889
# 199  2008        4  13141.920    9195.3  1857.661  1007.273   9920.4  212.174
# 200  2009        1  12925.410    9209.2  1558.494   996.287   9926.4  212.671
# 201  2009        2  12901.504    9189.0  1456.678  1023.528  10077.5  214.469
# 202  2009        3  12990.341    9256.0  1486.398  1044.088  10040.6  216.385
#
#          m1  tbilrate  unemp      pop  infl  realint
# 0     139.7      2.82    5.8  177.146  0.00     0.00
# 1     141.7      3.08    5.1  177.830  2.34     0.74
# 2     140.5      3.82    5.3  178.657  2.74     1.09
# 3     140.0      4.33    5.6  179.386  0.27     4.06
# 4     139.6      3.50    5.2  180.007  2.31     1.19
# ..      ...       ...    ...      ...   ...      ...
# 198  1474.7      1.17    6.0  305.270 -3.16     4.33
# 199  1576.5      0.12    6.9  305.952 -8.79     8.91
# 200  1592.8      0.22    8.1  306.547  0.94    -0.71
# 201  1653.6      0.18    9.2  307.226  3.37    -3.19
# 202  1673.9      0.12    9.6  308.013  3.56    -3.44
#
# [203 rows x 14 columns]

# %%
data["year"]
# Out:
# 0      1959
# 1      1959
# 2      1959
# 3      1959
# 4      1960
#        ...
# 198    2008
# 199    2008
# 200    2009
# 201    2009
# 202    2009
# Name: year, Length: 203, dtype: int64

# %%
data["quarter"]
# Out:
# 0      1
# 1      2
# 2      3
# 3      4
# 4      1
#       ..
# 198    3
# 199    4
# 200    1
# 201    2
# 202    3
# Name: quarter, Length: 203, dtype: int64

# %%
index = pd.PeriodIndex(year=data["year"], quarter=data["quarter"], freq="Q-DEC")
# Out:
# /tmp/ipykernel_3803/2492389853.py:1: FutureWarning: Constructing PeriodIndex from fields is deprecated. Use PeriodIndex.from_fields instead.
#   index = pd.PeriodIndex(year=data["year"], quarter=data["quarter"], freq="Q-DEC")

# %%
index
# Out:
# PeriodIndex(['1959Q1', '1959Q2', '1959Q3', '1959Q4', '1960Q1', '1960Q2',
#              '1960Q3', '1960Q4', '1961Q1', '1961Q2',
#              ...
#              '2007Q2', '2007Q3', '2007Q4', '2008Q1', '2008Q2', '2008Q3',
#              '2008Q4', '2009Q1', '2009Q2', '2009Q3'],
#             dtype='period[Q-DEC]', length=203)

# %%
data.index = index

# %%
data["infl"]
# Out:
# 1959Q1    0.00
# 1959Q2    2.34
# 1959Q3    2.74
# 1959Q4    0.27
# 1960Q1    2.31
#           ...
# 2008Q3   -3.16
# 2008Q4   -8.79
# 2009Q1    0.94
# 2009Q2    3.37
# 2009Q3    3.56
# Freq: Q-DEC, Name: infl, Length: 203, dtype: float64

# %% [markdown]
# # 11.6 Resampling and frequency conversion

# %%
dates = pd.date_range("2000-01-01", periods=100)

# %%
ts = pd.Series(np.random.standard_normal(len(dates)), index=dates)

# %%
ts
# Out:
# 2000-01-01   -0.126102
# 2000-01-02    0.294882
# 2000-01-03    0.780681
# 2000-01-04   -2.122881
# 2000-01-05    1.225697
#                 ...
# 2000-04-05   -0.596866
# 2000-04-06   -0.474361
# 2000-04-07    1.603004
# 2000-04-08    0.347000
# 2000-04-09    1.597286
# Freq: D, Length: 100, dtype: float64

# %%
ts.resample("M").mean()
# Out:
# /tmp/ipykernel_3803/3978117481.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   ts.resample("M").mean()
# 2000-01-31    0.339261
# 2000-02-29   -0.078206
# 2000-03-31    0.160753
# 2000-04-30    0.773637
# Freq: ME, dtype: float64

# %%
ts.resample("M", kind="period").mean()
# Out:
# /tmp/ipykernel_3803/1563622178.py:1: FutureWarning: The 'kind' keyword in Series.resample is deprecated and will be removed in a future version. Explicitly cast the index to the desired type instead
#   ts.resample("M", kind="period").mean()
# /tmp/ipykernel_3803/1563622178.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   ts.resample("M", kind="period").mean()
# 2000-01    0.339261
# 2000-02   -0.078206
# 2000-03    0.160753
# 2000-04    0.773637
# Freq: M, dtype: float64

# %% [markdown]
# # 11.6.1 Downsampling

# %%
dates = pd.date_range("2000-01-01", periods=12, freq="T")
# Out:
# /tmp/ipykernel_3803/1110584800.py:1: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   dates = pd.date_range("2000-01-01", periods=12, freq="T")

# %%
ts = pd.Series(np.arange(len(dates)), index=dates)

# %%
ts
# Out:
# 2000-01-01 00:00:00     0
# 2000-01-01 00:01:00     1
# 2000-01-01 00:02:00     2
# 2000-01-01 00:03:00     3
# 2000-01-01 00:04:00     4
# 2000-01-01 00:05:00     5
# 2000-01-01 00:06:00     6
# 2000-01-01 00:07:00     7
# 2000-01-01 00:08:00     8
# 2000-01-01 00:09:00     9
# 2000-01-01 00:10:00    10
# 2000-01-01 00:11:00    11
# Freq: min, dtype: int64

# %%
ts.resample("5min").sum()
# Out:
# 2000-01-01 00:00:00    10
# 2000-01-01 00:05:00    35
# 2000-01-01 00:10:00    21
# Freq: 5min, dtype: int64

# %%
ts.resample("5min", closed="right").sum()
# Out:
# 1999-12-31 23:55:00     0
# 2000-01-01 00:00:00    15
# 2000-01-01 00:05:00    40
# 2000-01-01 00:10:00    11
# Freq: 5min, dtype: int64

# %%
ts.resample("5min", closed="right", label="right").sum()
# Out:
# 2000-01-01 00:00:00     0
# 2000-01-01 00:05:00    15
# 2000-01-01 00:10:00    40
# 2000-01-01 00:15:00    11
# Freq: 5min, dtype: int64

# %%
from pandas.tseries.frequencies import to_offset

# %%
result = ts.resample("5min", closed="right", label="right").sum()

# %%
result.index = result.index + to_offset("-1s")

# %%
result
# Out:
# 1999-12-31 23:59:59     0
# 2000-01-01 00:04:59    15
# 2000-01-01 00:09:59    40
# 2000-01-01 00:14:59    11
# Freq: 5min, dtype: int64

# %%
ts = pd.Series(np.random.permutation(np.arange(len(dates))), index=dates)

# %%
ts.resample("5min").ohlc()
# Out:
#                      open  high  low  close
# 2000-01-01 00:00:00     3     9    3      9
# 2000-01-01 00:05:00     5    11    0      8
# 2000-01-01 00:10:00     1    10    1     10

# %% [markdown]
# # 11.6.2 Upsampling and interpolation

# %%
frame = pd.DataFrame(np.random.standard_normal((2, 4)),
                     index=pd.date_range("2000-01-01", periods=2, freq="W-WED"),
                     columns=["Colorado", "Texas", "New York", "Ohio"])

# %%
frame
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-05 -0.304879  1.150076  0.283366 -0.581182
# 2000-01-12 -0.870319  0.580885  1.433157  0.843500

# %%
df_daily = frame.resample("D").asfreq()

# %%
df_daily
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-05 -0.304879  1.150076  0.283366 -0.581182
# 2000-01-06       NaN       NaN       NaN       NaN
# 2000-01-07       NaN       NaN       NaN       NaN
# 2000-01-08       NaN       NaN       NaN       NaN
# 2000-01-09       NaN       NaN       NaN       NaN
# 2000-01-10       NaN       NaN       NaN       NaN
# 2000-01-11       NaN       NaN       NaN       NaN
# 2000-01-12 -0.870319  0.580885  1.433157  0.843500

# %%
frame.resample("D").ffill()
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-05 -0.304879  1.150076  0.283366 -0.581182
# 2000-01-06 -0.304879  1.150076  0.283366 -0.581182
# 2000-01-07 -0.304879  1.150076  0.283366 -0.581182
# 2000-01-08 -0.304879  1.150076  0.283366 -0.581182
# 2000-01-09 -0.304879  1.150076  0.283366 -0.581182
# 2000-01-10 -0.304879  1.150076  0.283366 -0.581182
# 2000-01-11 -0.304879  1.150076  0.283366 -0.581182
# 2000-01-12 -0.870319  0.580885  1.433157  0.843500

# %%
frame.resample("D").ffill(limit=2)
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-05 -0.304879  1.150076  0.283366 -0.581182
# 2000-01-06 -0.304879  1.150076  0.283366 -0.581182
# 2000-01-07 -0.304879  1.150076  0.283366 -0.581182
# 2000-01-08       NaN       NaN       NaN       NaN
# 2000-01-09       NaN       NaN       NaN       NaN
# 2000-01-10       NaN       NaN       NaN       NaN
# 2000-01-11       NaN       NaN       NaN       NaN
# 2000-01-12 -0.870319  0.580885  1.433157  0.843500

# %%
frame.resample("W-THU").ffill()
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-06 -0.304879  1.150076  0.283366 -0.581182
# 2000-01-13 -0.870319  0.580885  1.433157  0.843500

# %%
frame
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-05 -0.304879  1.150076  0.283366 -0.581182
# 2000-01-12 -0.870319  0.580885  1.433157  0.843500

# %% [markdown]
# # 11.6.3 Resampling base on usage period

# %%
frame = pd.DataFrame(np.random.standard_normal((24, 4)),
                     index=pd.period_range("1-2000", "12-2001", freq="M"),
                     columns=["Colorado", "Texas", "New York", "Ohio"])

# %%
frame.head()
# Out:
#          Colorado     Texas  New York      Ohio
# 2000-01  0.333199  0.037982  0.277130  1.706488
# 2000-02  0.295721 -0.436448  0.159202 -0.196782
# 2000-03  1.404427 -0.219272  0.633641  1.363800
# 2000-04 -1.326863  0.577875 -1.327662  1.455564
# 2000-05 -1.066137  2.038474  0.707125 -0.314252

# %%
annual_frame = frame.resample("A-DEC").mean()
# Out:
# /tmp/ipykernel_3803/468843495.py:1: FutureWarning: 'A-DEC' is deprecated and will be removed in a future version, please use 'Y-DEC' instead.
#   annual_frame = frame.resample("A-DEC").mean()

# %%
annual_frame
# Out:
#       Colorado     Texas  New York      Ohio
# 2000 -0.246581  0.117022  0.139854  0.384661
# 2001 -0.135319 -0.311507 -0.249865 -0.449357

# %%
annual_frame.resample("Q-DEC").ffill()
# Out:
#         Colorado     Texas  New York      Ohio
# 2000Q1 -0.246581  0.117022  0.139854  0.384661
# 2000Q2 -0.246581  0.117022  0.139854  0.384661
# 2000Q3 -0.246581  0.117022  0.139854  0.384661
# 2000Q4 -0.246581  0.117022  0.139854  0.384661
# 2001Q1 -0.135319 -0.311507 -0.249865 -0.449357
# 2001Q2 -0.135319 -0.311507 -0.249865 -0.449357
# 2001Q3 -0.135319 -0.311507 -0.249865 -0.449357
# 2001Q4 -0.135319 -0.311507 -0.249865 -0.449357

# %%
annual_frame.resample("Q-DEC", convention="end").asfreq()
# Out:
#         Colorado     Texas  New York      Ohio
# 2000Q4 -0.246581  0.117022  0.139854  0.384661
# 2001Q1       NaN       NaN       NaN       NaN
# 2001Q2       NaN       NaN       NaN       NaN
# 2001Q3       NaN       NaN       NaN       NaN
# 2001Q4 -0.135319 -0.311507 -0.249865 -0.449357

# %%
annual_frame.resample("Q-MAR").ffill()
# Out:
#         Colorado     Texas  New York      Ohio
# 2000Q4 -0.246581  0.117022  0.139854  0.384661
# 2001Q1 -0.246581  0.117022  0.139854  0.384661
# 2001Q2 -0.246581  0.117022  0.139854  0.384661
# 2001Q3 -0.246581  0.117022  0.139854  0.384661
# 2001Q4 -0.135319 -0.311507 -0.249865 -0.449357
# 2002Q1 -0.135319 -0.311507 -0.249865 -0.449357
# 2002Q2 -0.135319 -0.311507 -0.249865 -0.449357
# 2002Q3 -0.135319 -0.311507 -0.249865 -0.449357

# %% [markdown]
# # 11.6.4 Resample the grouping time

# %%
N = 15

# %%
times = pd.date_range("2017-05-20 00:00", freq="1min", periods=N)

# %%
df = pd.DataFrame({"time": times,
                   "value": np.arange(N)})

# %%
df
# Out:
#                   time  value
# 0  2017-05-20 00:00:00      0
# 1  2017-05-20 00:01:00      1
# 2  2017-05-20 00:02:00      2
# 3  2017-05-20 00:03:00      3
# 4  2017-05-20 00:04:00      4
# 5  2017-05-20 00:05:00      5
# 6  2017-05-20 00:06:00      6
# 7  2017-05-20 00:07:00      7
# 8  2017-05-20 00:08:00      8
# 9  2017-05-20 00:09:00      9
# 10 2017-05-20 00:10:00     10
# 11 2017-05-20 00:11:00     11
# 12 2017-05-20 00:12:00     12
# 13 2017-05-20 00:13:00     13
# 14 2017-05-20 00:14:00     14

# %%
df.set_index("time").resample("5min").count()
# Out:
#                      value
# time
# 2017-05-20 00:00:00      5
# 2017-05-20 00:05:00      5
# 2017-05-20 00:10:00      5

# %%
df2 = pd.DataFrame({"time": times.repeat(3),
                    "key": np.tile(["a", "b", "c"], N),
                    "value": np.arange(N * 3.)})

# %%
df2.head(7)
# Out:
#                  time key  value
# 0 2017-05-20 00:00:00   a    0.0
# 1 2017-05-20 00:00:00   b    1.0
# 2 2017-05-20 00:00:00   c    2.0
# 3 2017-05-20 00:01:00   a    3.0
# 4 2017-05-20 00:01:00   b    4.0
# 5 2017-05-20 00:01:00   c    5.0
# 6 2017-05-20 00:02:00   a    6.0

# %%
time_key = pd.Grouper(freq="5min")

# %%
resampled = (df2.set_index("time").groupby(["key", time_key]).sum())

# %%
resampled
# Out:
#                          value
# key time
# a   2017-05-20 00:00:00   30.0
#     2017-05-20 00:05:00  105.0
#     2017-05-20 00:10:00  180.0
# b   2017-05-20 00:00:00   35.0
#     2017-05-20 00:05:00  110.0
#     2017-05-20 00:10:00  185.0
# c   2017-05-20 00:00:00   40.0
#     2017-05-20 00:05:00  115.0
#     2017-05-20 00:10:00  190.0

# %%
resampled.reset_index()
# Out:
#   key                time  value
# 0   a 2017-05-20 00:00:00   30.0
# 1   a 2017-05-20 00:05:00  105.0
# 2   a 2017-05-20 00:10:00  180.0
# 3   b 2017-05-20 00:00:00   35.0
# 4   b 2017-05-20 00:05:00  110.0
# 5   b 2017-05-20 00:10:00  185.0
# 6   c 2017-05-20 00:00:00   40.0
# 7   c 2017-05-20 00:05:00  115.0
# 8   c 2017-05-20 00:10:00  190.0

# %% [markdown]
# # 11.7 Move Window Function
